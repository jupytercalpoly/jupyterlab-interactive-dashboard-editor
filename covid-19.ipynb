# %%
print ("My Dashboard")
# Out:
# My Dashboard

# %%
print ("Created by Julia Huynh")
# Out:
# Created by Julia Huynh

# %%
import ipywidgets as widgets

from IPython.display import display
w = widgets.IntSlider()
display(w)
# Out:
# IntSlider(value=0)

# %% [markdown]
# COVID-19 Data: United States vs Italy

# %%
import ipywidgets as widgets

from IPython.display import display
w = widgets.IntSlider()
display(w)
# Out:
# IntSlider(value=0)

# %%
print ("Have a nice day!")
# Out:
# Have a nice day!
